# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing our final Dataset

# %%
df = pd.read_csv(r"C:\Users\bhask\OneDrive\Desktop\honda_cars_details.csv")
df
# Out:
#            Cars  Kilometers  Year Fuel Type Transmission  Price(Lakh)
# 0    Honda City       29274  2022    Diesel       Manual        18.08
# 1    Honda City       20465  2021    Petrol    Automatic        14.73
# 2    Honda City       18601  2019    Petrol    Automatic        14.37
# 3   Honda Amaze       55601  2019    Petrol    Automatic        18.87
# 4    Honda WR-V        8629  2020    Petrol    Automatic        15.00
# 5    Honda Jazz       32496  2021    Petrol    Automatic        15.62
# 6    Honda City       36110  2020    Petrol    Automatic        15.09
# 7    Honda City       51824  2020    Diesel       Manual        13.87
# 8   Honda Amaze       65163  2021    Petrol    Automatic        13.66
# 9    Honda WR-V       33306  2021    Diesel       Manual        13.86
# 10   Honda Jazz       14172  2019    Petrol    Automatic        13.89
# 11   Honda City       50365  2020    Petrol    Automatic        13.57
# ...

# %% [markdown]
# # Data Analysis

# %% [markdown]
# # Finding The Null values

# %%
 df.isnull().sum()
# Out:
# Cars            0
# Kilometers      0
# Year            0
# Fuel Type       0
# Transmission    0
# Price(Lakh)     0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Getting information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Cars          31 non-null     object
#  1   Kilometers    31 non-null     int64
#  2   Year          31 non-null     int64
#  3   Fuel Type     31 non-null     object
#  4   Transmission  31 non-null     object
#  5   Price(Lakh)   31 non-null     float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.6+ KB

# %% [markdown]
# ## Finding Maximum and Minimum Values in each column

# %%
col_max = df.max(axis=0)
col_max
# Out:
# Cars            Honda WR-V
# Kilometers          127904
# Year                  2022
# Fuel Type           Petrol
# Transmission        Manual
# Price(Lakh)          18.87
# dtype: object

# %%
col_min = df.min(axis=0)
col_min
# Out:
# Cars            Honda Amaze
# Kilometers             3306
# Year                   2019
# Fuel Type            Diesel
# Transmission      Automatic
# Price(Lakh)           12.34
# dtype: object

# %% [markdown]
# ## Cars vs Kilometers

# %%
df_new = df.iloc[:, [0,1]]
df_new
# Out:
#            Cars  Kilometers
# 0    Honda City       29274
# 1    Honda City       20465
# 2    Honda City       18601
# 3   Honda Amaze       55601
# 4    Honda WR-V        8629
# 5    Honda Jazz       32496
# 6    Honda City       36110
# 7    Honda City       51824
# 8   Honda Amaze       65163
# 9    Honda WR-V       33306
# 10   Honda Jazz       14172
# 11   Honda City       50365
# 12  Honda Amaze       49559
# 13   Honda WR-V       13989
# 14   Honda City      127904
# 15   Honda Jazz        7459
# 16   Honda City       65163
# 17   Honda WR-V        3306
# 18  Honda Amaze       14172
# 19   Honda WR-V       50365
# 20   Honda City       29274
# 21   Honda City       20465
# 22   Honda City       18601
# 23  Honda Amaze       33306
# 24   Honda Jazz        8487
# 25   Honda WR-V       65163
# 26   Honda City       14172
# 27  Honda Amaze       42379
# 28   Honda WR-V       26226
# 29   Honda WR-V       52310
# 30   Honda WR-V       42379

# %% [markdown]
# # Cars vs Years

# %%
df_new = df.iloc[:, [0,2]]
df_new
# Out:
#            Cars  Year
# 0    Honda City  2022
# 1    Honda City  2021
# 2    Honda City  2019
# 3   Honda Amaze  2019
# 4    Honda WR-V  2020
# 5    Honda Jazz  2021
# 6    Honda City  2020
# 7    Honda City  2020
# 8   Honda Amaze  2021
# 9    Honda WR-V  2021
# 10   Honda Jazz  2019
# 11   Honda City  2020
# 12  Honda Amaze  2020
# 13   Honda WR-V  2021
# 14   Honda City  2021
# 15   Honda Jazz  2022
# 16   Honda City  2021
# 17   Honda WR-V  2020
# 18  Honda Amaze  2019
# 19   Honda WR-V  2020
# 20   Honda City  2022
# 21   Honda City  2021
# 22   Honda City  2019
# 23  Honda Amaze  2020
# 24   Honda Jazz  2019
# 25   Honda WR-V  2020
# 26   Honda City  2019
# 27  Honda Amaze  2021
# 28   Honda WR-V  2019
# 29   Honda WR-V  2020
# 30   Honda WR-V  2019

# %% [markdown]
# ### Detecting the outliers in column Kilometers

# %%
z_scores = np.abs((df['Kilometers'] - df['Kilometers'].mean()) / df['Kilometers'].std())

# Define threshold for outliers (e.g., Z-score > 3)
threshold = 3
outliers = df[z_scores > threshold]

print("Outliers detected by Z-score method in Kilometers column:")
print(outliers)
# Out:
# Outliers detected by Z-score method in Kilometers column:
#           Cars  Kilometers  Year Fuel Type Transmission  Price(Lakh)
# 14  Honda City      127904  2021    Diesel       Manual        15.38

# %%
df_no_outliers = df[z_scores <= threshold]

# Display DataFrame after removing outliers
print("\nDataFrame after removing outliers:")
print(df_no_outliers)
# Out:
# DataFrame after removing outliers:
#            Cars  Kilometers  Year Fuel Type Transmission  Price(Lakh)
# 0    Honda City       29274  2022    Diesel       Manual        18.08
# 1    Honda City       20465  2021    Petrol    Automatic        14.73
# 2    Honda City       18601  2019    Petrol    Automatic        14.37
# 3   Honda Amaze       55601  2019    Petrol    Automatic        18.87
# 4    Honda WR-V        8629  2020    Petrol    Automatic        15.00
# 5    Honda Jazz       32496  2021    Petrol    Automatic        15.62
# 6    Honda City       36110  2020    Petrol    Automatic        15.09
# 7    Honda City       51824  2020    Diesel       Manual        13.87
# 8   Honda Amaze       65163  2021    Petrol    Automatic        13.66
# 9    Honda WR-V       33306  2021    Diesel       Manual        13.86
# 10   Honda Jazz       14172  2019    Petrol    Automatic        13.89
# 11   Honda City       50365  2020    Petrol    Automatic        13.57
# ...

# %% [markdown]
# ## Data Visualization

# %%
# Plotting the barplot
plt.figure(figsize=(4,6))
sns.barplot(data=df, x='Cars', y='Price(Lakh)')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to make room for rotated labels
plt.show()

# %%
# Plotting the barplot
plt.figure(figsize=(4,6))
sns.barplot(data=df, x='Cars', y='Transmission')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to make room for rotated labels
plt.show()

# %% [markdown]
# # Stacked Bar chart

# %%
transmission_counts = df.groupby(['Cars', 'Transmission']).size().reset_index(name='Counts')

# Pivot the data to make 'Transmission' types as columns
transmission_pivot = transmission_counts.pivot(index='Cars', columns='Transmission', values='Counts').fillna(0)

# Plotting stacked bar chart
plt.figure(figsize=(10, 6))
transmission_pivot.plot(kind='bar', stacked=True)
plt.title('Transmission Distribution by Car')
plt.xlabel('Cars')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.legend(title='Transmission')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Scatter plot

# %%
plt.figure(figsize=(4, 4))  # Adjust the figure size to make the graph smaller

plt.scatter(df['Cars'], df['Price(Lakh)'])

plt.xlabel('Cars')
plt.ylabel('Price')

plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.grid(False, axis='x')  # Remove the grid lines on the x-axis

plt.show()

# %% [markdown]
# ## Finally calculating the average price

# %%
average_price = df['Price(Lakh)'].mean()

print(f"Average Price: {average_price:.2f} Lakh")
# Out:
# Average Price: 14.63 Lakh

# %% [markdown]
# # Finally calculating the average Kilometers

# %%
average_kilometers = df['Kilometers'].mean()

print(f"Average Kilometers: {average_kilometers:.2f}Km")
# Out:
# Average Kilometers: 35505.97Km
